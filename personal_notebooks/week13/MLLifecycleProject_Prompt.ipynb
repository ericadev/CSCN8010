# %% [markdown]
# -----
#
# ## Tutorial - A full lifecycle of a machine learning project, from initial setup and data versioning to training, evaluation, and finally deploying a usable application.

# %% [markdown]
# Tutorial Coming soon...<br/><br/><br/><br/>
#
# ## Vibe Programming: How did we produce this tutorial? 🚀
#
# Here is a comprehensive set of prompts, structured using the Curriculum Learning technique, that would guide an LLM like me to produce the entire 13-step tutorial, including all the necessary debugging and refinement steps we encountered.
#
# This can serve as a template for your students on how to conduct a complex, iterative session to build a full project.
#
# ***
# ### Prompt 1: Initial Context and Role Definition
#
# Implementation notes:
# - The prompt was developed using a technique known as Curriculum Learning. In the context of prompt engineering, this approach involves structuring prompts in a way that gradually increases in complexity. The user starts with simpler concepts and progressively introduces more complex ideas and terminology. This method helps the LLM build a solid foundation before tackling more advanced topics, ultimately enabling it to infer and generate new ideas based on its accumulated knowledge
#
# Role--------------------
# I am a professor of Machine Learning at the college level. You are an experienced Machine Learning Engineer and Data Scientist.
#
# Context (1)----------------
# This term, I am teaching Foundations of Machine Learning to entry-level students. The topic for this week is Introduction to Convolutional Neural Networks (CNNs).
# We want to train a Convolutional Neural Network using PyTorch using the Dogs vs. Cats dataset, originally from a Kaggle competition, that contains a total of 25,000 labeled images.
# The Training set consists of:
# - 10,000 images of cats
# - 10,000 images of dogs
# The Test set consists of:
# - 2,500 images of cats
# - 2,500 images of dogs
# This dataset is often used for binary image classification tasks and is popular in deep learning tutorials and competitions.
# Say if you agree with this information. You may add any other you deem relevant.
#
# ***
# ### Prompt 2: Introducing a Technical Constraint (Data Management)
#
# Context (2)----------------
# But, we are having issues pushing large data sets to GitHub, as GitHub imposes the following limits on file and repository sizes:
# Soft limit: Files over 50 MB will trigger a warning.
# Hard limit: Files over 100 MB are blocked from being pushed to the repository.
# Browser uploads: Limited to 25 MB per file.
# And there are also Repository Size Limits.
# Recommended: Keep repositories under 1 GB.
# Soft cap: GitHub starts issuing warnings if a repository exceeds 1 GB.
# Hard cap: Repositories over 5 GB may be restricted or flagged for abuse.
# To manage large files (e.g., datasets, media), GitHub recommends using Git Large File Storage (Git LFS), which allows you to track and store large files outside the regular Git history.
# Say if you agree with this information. You may add any other you deem relevant.
#
# ***
# ### Prompt 3: Synthesizing Context and Requesting a Project Plan
#
# Output(1)--------------------
# You said that, "While Git LFS is a great tool, it has its own costs and complexities... For a class with many students, this could become a factor. "
# And you recommended:
# DVC is a powerful open-source tool built specifically for machine learning projects... DVC creates small "pointer" files that you commit to Git...
#
# Expectations (1)--------------
# Guide me step by step on how to implement this project, which I now re-phrase:
# Train a Convolutional Neural Network using PyTorch using the Dogs vs. Cats dataset for creating a binary image classification application... The project will use Git alongside DVC, using the former to version the code, and the latter to version the data.
#
# Expectations (2)--------------
# Start by listing the steps you will take me through, but not actually implementing them yet.
# Show me the steps in a table with a step number in column 1, its name in column 2 and a description in column 3.
# Wait for me to tell you when to start.
# Show me how to document and implement one step at a time.
# I will produce a Jupyter Notebook called "CNN_CatsDogs_Pytorch_GitHub_DVC.ipynb" where I will add Markdown and Python code cells for every step that you teach me.
#
# Output-------------------
# For every step, produce Markdown and Python code that I can easily copy and paste to my notebook in Visual Studio Code.
#
# Tell me when you are ready to start, and I'll give you the signal to proceed.
#
# ***
# ### Prompts for Step-by-Step Implementation and Debugging
#
# * **Prompt 4:** "Ok, proceed"
# * **Prompt 5:** "Go to the next step"
# * **Prompt 6 (Error):** "The Kaggle download returned an error: 403 Client Error: Forbidden for url..."
# * **Prompt 7 (Error):** "There is no 'I Understand and Accept' button at the end. The rest of the page is blurred."
# * **Prompt 8 (Error):** "I am logged in. I confirmed by signing off and on again."
# * **Prompt 9 (Pivot):** "Ok, in that case, let's redo step 2, markdown, and code. Regenerate it."
# * **Prompt 10 (Correction):** "I followed your instructions and downloaded the dataset I found on Microsoft's page. FYI - the name of the file is 'kagglecatsanddogs\_5340.zip'"
# * **Prompt 11 (Error):** "Part #2 generated this error: ModuleNotFoundError: No module named 'PIL'... What is the right pip command?"
# * **Prompt 12:** "Go to the next step"
# * **Prompt 13 (Error):** "Google Drive suddenly blocked an app... How can I delete the remote called 'myremote'?"
# * **Prompt 14 (Error):** "I removed the remote and tried again, but now I get this error: ERROR: failed to push data to the cloud - Unable to acquire lock..."
# * **Prompt 15 (Error):** "The command threw an error: ERROR: argument command: invalid choice: 'unlock'..."
# * **Prompt 16:** "give me the equivalent Windows Powershell command"
# * **Prompt 17:** "Give me the equivalent CMD command"
# * **Prompt 18 (Error):** "The process cannot access the file because it is being used by another process."
# * **Prompt 19 (Error):** "When I run: !dvc remote add... Is something wrong?"
# * **Prompt 20 (Clarification):** "I don't know if I should cancel the running code because there are still three more commands..."
# * **Prompt 21 (Error):** "Ok, I did that but now I get: ERROR: failed to push data to the cloud - Unable to acquire lock..."
# * **Prompt 22 (Error):** "Ok, so I added the command and now the code cell looks like... But when I run it, I get: The process cannot access the file..."
# * **Prompt 23 (Error):** "ERROR: you are not inside of a DVC repository..."
# * **Prompt 24 (Error):** "Ok, closed VSCode and re-opened. I re-activated .venv Then I ran... and I get... ERROR: failed to push data..."
# * **Prompt 25 (Error):** "[WinError 2] The system cannot find the file specified... ERROR: failed to push data..."
# * **Prompt 26 (Info):** "This is my current directory... Next, I ran... And then... And then I ran... (Pasting all outputs from terminal and dvc doctor)"
# * **Prompt 27 (Error):** "dvc : The term 'dvc' is not recognized as the name of a cmdlet..."
# * **Prompt 28 (Error):** "dvc push ERROR: failed to push data to the cloud - Unable to acquire lock..."
# * **Prompt 29 (Insight):** "I opened the task manager and see that dvc is running as a process. Should I delete the task so I can then remove the lock file?"
# * **Prompt 30 (Info):** "(Pasting the dvc push output with the browser auth link)"
# * **Prompt 31 (Error):** "When I point my browser at... I get: This app is blocked"
# * **Prompt 32 (Error):** "ERROR: unexpected error - : <HttpError 404...>"
# * **Prompt 33 (Hypothesis):** "I don't know what scope to set here... I uploaded an image with the options I have. Help me choose - this may be the problem. Do you agree or not?"
# * **Prompt 34 (Verification):** "Following your instructions: Go to your Google Drive... I uploaded an image of the page, along with the URL. Is this where I need to go?"
# * **Prompt 35 (Error):** "(Pasting the persistent HttpError 404)"
# * **Prompt 36 (Verification):** "I followed your instructions. Uploaded a screenshot of what I'm seeing. (Screenshot of API enabled)"
# * **Prompt 37 (Error):** "(Pasting the Remove-Item : Cannot find path error)"
# * **Prompt 38 (Error):** "(Pasting the persistent HttpError 404 again)"
# * **Prompt 39 (Error):** "python .\\test_drive.py Attempting to authenticate... ❌ Authentication Failed: 'client_config_file'"
# * **Prompt 40 (Error):** "(Pasting the dir output and the same client_config_file error)"
# * **Prompt 41 (Info):** "(Pasting the output showing the programmatic script creation also failed)"
#
# ***
# ### Prompts for Continuing the ML Workflow
#
# * **Prompt 42:** "The errors continue. Let's move on. We'll come back and fix this step later. You recall you produced the code for step 5?"
# * **Prompt 43 (Error):** "Ok, fixed. Now I'm running: --- 4. Create DataLoaders --- and I get this error: FileNotFoundError..."
# * **Prompt 44 (Error):** "Ok, fixed. Now I'm running... and I get this error: RuntimeError: Numpy is not available..."
# * **Prompt 45 (Error):** "Now I get: NameError: name 'DataLoader' is not defined"
# * **Prompt 46:** "Ok, done. Now move on to the next step." (for Step 6)
# * **Prompt 47:** "Ok, move on to step 7."
# * **Prompt 48:** "The model is training. While it does, let's move on to step 9."
# * **Prompt 49:** "Sorry, I skipped step 8. Let's go there first."
# * **Prompt 50 (Info):** "I am running this Jupyter Notebook on a laptop with the specs I uploaded... Is there any way to optimize the step 8 code so it takes advantage of the GPUs?"
#
# ***
# ### Prompts for Extending the Project Plan
#
# * **Prompt 51:** "Looks like we are done with the original 9-step plan. Anything to add?"
# * **Prompt 52:** "I agree. Here is the original table you produced... Add the three new steps to it and re-generate the table as markdown so I can update my README.md"
# * **Prompt 53:** "Ok, so produce step 10."
# * **Prompt 54:** "Explain how the study and its report on the best trial takes into account the training we executed in step 7."
# * **Prompt 55:** "I agree. Add this to the currently 10-step process table as step 11, and re-number the current steps 10, 11 and 12 as 11, 12 and 13. Regenerate as markdown..."
# * **Prompt 56:** "Ok, so while step 10 runs, let's generate [the new] step 11."
# * **Prompt 57:** "Now do step 12."
# * **Prompt 58:** "Now do step 13."
#
# ***
# ### Final Prompt: A Request for this summary of the GPT session
#
# Expectations (3)--------------
# I want to show my students how to engage in a session with you, an LLM, and for that, I want you to produce the entire set of prompts that would let you produce every single markdown and code cell you have generated here, including the table for the README.md, and everything needed to implement the 13 steps. Make sure to capture all the prompts and interactions needed to resolve issues with DVC and others we encountered.
#
# Output (3)-------------------
# Produce the prompt with highly technical language, as per your role: You are an experienced Machine Learning Engineer and Data Scientist.
# Use the Curriculum Learning technique to structure the prompts in a way that gradually increases their complexity.
# Produce this material as markdown that I can copy to a cell in a Jupyter Notebook.
